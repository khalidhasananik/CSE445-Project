# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/dataset.csv'
df = pd.read_csv(file_path)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['District'] = label_encoder.fit_transform(df['District'])
df = df.drop(columns=['Year'])

# %%
df = df.apply(pd.to_numeric, errors='coerce')
df.ffill(inplace = True)
df['Total Cases'] = df.iloc[:, 37:49].sum(axis=1)
df = df.drop(df.columns[37:49], axis=1)

# %%
print(df)
# Out:
#      District  Temperature_1  Temperature_2  Temperature_3  Temperature_4  \
# 0           0      20.000000      22.680000      26.655000      29.470000
# 1           0      19.385000      21.440000      26.865000      29.515000
# 2           0      20.640000      23.015000      28.825000      30.685000
# 3           0      18.301344      20.119196      27.013710      29.800000
# 4           0      18.979301      22.850893      25.262500      28.902778
# ..        ...            ...            ...            ...            ...
# 379        63      17.180000      19.535000      23.945000      25.630000
# 380        63      17.235000      20.965000      24.980000      27.810000
# 381        63      15.633737      16.521280      24.450269      25.818472
# 382        63      15.571102      20.074256      23.375269      26.259583
# 383        63      20.700000      19.900000      23.800000      31.900000
#
#      Temperature_5  Temperature_6  Temperature_7  Temperature_8  \
# 0        31.440000      30.825000      30.225000      29.810000
# 1        29.675000      29.740000      29.930000      29.705000
# 2        30.495000      29.525000      29.705000      29.815000
# 3        28.714113      28.780694      28.474731      28.051075
# 4        29.265188      29.758750      28.735887      28.389382
# ..             ...            ...            ...            ...
# 379      27.255000      29.500000      29.135000      30.530000
# 380      27.750000      29.605000      30.140000      29.690000
# 381      26.439113      26.878750      28.829032      28.573118
# 382      27.283468      28.568889      28.688844      28.272177
# 383      33.200000      29.000000      28.500000      30.400000
#
#      Temperature_9  ...  Humidity_3  Humidity_4  Humidity_5  Humidity_6  \
# 0        29.360000  ...   72.610000   76.130000   77.870000   83.830000
# 1        29.955000  ...   70.710000   74.930000   78.840000   81.700000
# 2        29.310000  ...   76.350000   77.400000   79.650000   84.130000
# 3        27.631944  ...   61.587366   73.231944   80.084677   82.306944
# 4        28.104583  ...   70.592742   72.080556   75.489247   81.365278
# ..             ...  ...         ...         ...         ...         ...
# 379      28.935000  ...   64.230000   64.800000   72.870000   83.670000
# 380      29.840000  ...   66.290000   69.030000   78.870000   80.900000
# 381      27.100139  ...   64.008065   79.330556   82.030914   87.273611
# 382      28.409583  ...   63.779570   64.408333   69.513441   77.947222
# 383      28.700000  ...   26.000000   20.000000   17.000000   78.000000
#
#      Humidity_7  Humidity_8  Humidity_9  Humidity_10  Humidity_11  Total Cases
# 0     86.940000   86.970000   88.270000    85.810000    83.230000          0.0
# 1     89.000000   83.230000   85.000000    82.230000    78.430000          0.0
# 2     87.580000   86.770000   88.100000    86.870000    85.430000          0.0
# 3     82.955645   85.247312   87.118056    83.580645    73.425000          0.0
# 4     84.272849   86.713710   87.541667    81.279570    78.305556          0.0
# ..          ...         ...         ...          ...          ...          ...
# 379   81.900000   83.970000   79.630000    79.650000    76.670000          0.0
# 380   81.770000   84.420000   81.130000    82.420000    77.470000          0.0
# 381   81.790323   82.845430   87.572222    82.150538    71.856944          0.0
# 382   84.483871   87.098118   85.609722    81.091398    70.213889          0.0
# 383   85.000000   72.000000   81.000000    79.000000    70.213889          0.0
#
# [384 rows x 37 columns]

# %%
print(df.dtypes)
# Out:
# District            int64
# Temperature_1     float64
# Temperature_2     float64
# Temperature_3     float64
# Temperature_4     float64
# Temperature_5     float64
# Temperature_6     float64
# Temperature_7     float64
# Temperature_8     float64
# Temperature_9     float64
# Temperature_10    float64
# Temperature_11    float64
# Temperature_12    float64
# Rainfall_1        float64
# Rainfall_2        float64
# Rainfall_3        float64
# Rainfall_4        float64
# Rainfall_5        float64
# Rainfall_6        float64
# Rainfall_7        float64
# Rainfall_8        float64
# Rainfall_9        float64
# Rainfall_10       float64
# Rainfall_11       float64
# Rainfall_12       float64
# Humidity_1        float64
# Humidity_2        float64
# Humidity_3        float64
# Humidity_4        float64
# Humidity_5        float64
# Humidity_6        float64
# Humidity_7        float64
# Humidity_8        float64
# Humidity_9        float64
# Humidity_10       float64
# Humidity_11       float64
# Total Cases       float64
# dtype: object

# %%
X = df.drop(columns = ['Total Cases'])
y = df['Total Cases']

# %%
#Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
df.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 37 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   District        384 non-null    int64
#  1   Temperature_1   384 non-null    float64
#  2   Temperature_2   384 non-null    float64
#  3   Temperature_3   384 non-null    float64
#  4   Temperature_4   384 non-null    float64
#  5   Temperature_5   384 non-null    float64
#  6   Temperature_6   384 non-null    float64
#  7   Temperature_7   384 non-null    float64
#  8   Temperature_8   384 non-null    float64
#  9   Temperature_9   384 non-null    float64
#  10  Temperature_10  384 non-null    float64
#  11  Temperature_11  384 non-null    float64
#  12  Temperature_12  384 non-null    float64
#  13  Rainfall_1      384 non-null    float64
#  14  Rainfall_2      384 non-null    float64
#  15  Rainfall_3      384 non-null    float64
#  16  Rainfall_4      384 non-null    float64
#  17  Rainfall_5      384 non-null    float64
#  18  Rainfall_6      384 non-null    float64
#  19  Rainfall_7      384 non-null    float64
#  20  Rainfall_8      384 non-null    float64
#  21  Rainfall_9      384 non-null    float64
#  22  Rainfall_10     384 non-null    float64
#  23  Rainfall_11     384 non-null    float64
#  24  Rainfall_12     384 non-null    float64
#  25  Humidity_1      384 non-null    float64
#  26  Humidity_2      384 non-null    float64
#  27  Humidity_3      384 non-null    float64
#  28  Humidity_4      384 non-null    float64
#  29  Humidity_5      384 non-null    float64
#  30  Humidity_6      384 non-null    float64
#  31  Humidity_7      384 non-null    float64
#  32  Humidity_8      384 non-null    float64
#  33  Humidity_9      384 non-null    float64
#  34  Humidity_10     384 non-null    float64
#  35  Humidity_11     384 non-null    float64
#  36  Total Cases     384 non-null    float64
# dtypes: float64(36), int64(1)
# memory usage: 111.1 KB

# %%
model = SVR(kernel='rbf')
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
y.pred = model.predict(X_test)

# %%
y_pred = model.predict(X_test)
for actual, predicted in zip(y_test, y_pred):
    print(f"Actual: {actual}, Predicted: {predicted}")
# Out:
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0
# Actual: 0.0, Predicted: 0.0

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results)
# Out:
#      Actual  Predicted
# 268     0.0        0.0
# 250     0.0        0.0
# 355     0.0        0.0
# 332     0.0        0.0
# 56      0.0        0.0
# ..      ...        ...
# 104     0.0        0.0
# 167     0.0        0.0
# 63      0.0        0.0
# 233     0.0        0.0
# 84      0.0        0.0
#
# [77 rows x 2 columns]

# %%
plt.scatter(range(len(y_test)), y_test, color='blue', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', label='Predicted')
plt.legend()
plt.title('Actual vs Predicted Values')
plt.show()
